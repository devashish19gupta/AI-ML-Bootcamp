# %% [markdown]
# <div class="alert alert-block alert-success">
#     <font size ="4">
#  Name: Devashish Kumar

# %% [markdown]
# # Accessing Data in Jupyter Notebook

# %% [markdown]
# ## Most popular data sources

# %% [markdown]
# - <b>Files: </b> CSV, Excel, JSON, TXTs, and Pickle, that can store structured and unstructured data. These files are stored in local or cloud storage and can be accessed using Python in Jupyter.<br><br>
#
# - <b>Databases and Data warehouse:</b> Data can be stored in different relational and non-relational databases and data warehouses such as MySQL, PostgreSQL, MongoDB, Redshift, and Snowflake.<br><br>
#
# - <b>APIs:</b> Data can also be accessed through APIs from multiple endpoints that sometimes may or may not need authentication.<br><br>
#
# - <b>Dataset Repositories:</b> Finally, different platforms provide open source datasets for ML and AI tasks such as Kaggle, Data.world, or Hugging Face. You can load data directly from these platforms.

# %%
from IPython.display import Image
Image("CSV2.png")

# %%
from IPython.display import Image
Image("excel.png") # File path of excel.png if image is not placed in the same folder

# %%
from IPython.display import Image
Image("json.png") # JavaScript Object Notation

# %% [markdown]
# ## Pre-requisites Packages

# %% [markdown]
# For loading the data from the APIs or websites you will also require the requests package which can be downloaded as follows:
#
# - pip install pandas
# - pip install requests
# - pip install xlrd #to read data from excel sheet
# - import sqlite3 as sql
# - pip install mysql-connector
# - import requests
# - pip install pandas_datareader #Accessing financial data using pandas_datareader

# %%
import pandas as pd

# %% [markdown]
# ## Reading Data from Excel Files

# %%
# excel absolute file path
excel_file = 'iris.xls' # no file path as it is placed in the same folder of notebook

# read data from an excel file
iris_data = pd.read_excel(excel_file, sheet_name='Data') # excel_file

#iris_data = pd.read_excel('iris.xls', sheet_name='Data') # excel_file

# to read csv file:--> pd.read_csv("")

# check the first few rows of data loaded from Excel
#iris_data.tail(10)
iris_data.head()
# Out:
#    Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0           1          0.2           1.4          3.5           5.1
# 1           1          0.2           1.4          3.0           4.9
# 2           1          0.2           1.3          3.2           4.7
# 3           1          0.2           1.5          3.1           4.6
# 4           1          0.2           1.4          3.6           5.0
#
#   Species_name
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa

# %% [markdown]
# ### Other arguments of the read_excel() method you might want to use are:
#
# - header: Row (0-indexed) to use for the column labels. By default, it is inferred, but you can set it to None if there's no header.
#
# - names: This is a list corresponding to the column names. Use this if you want to override or set column names.
#
# - usecols: A list of columns or column range (e.g., 'A:D') to import from the Excel file.
#
# - dtype: Dict of column name to data type. If not provided, pandas will try to infer the data type.

# %%
iris_data = pd.read_excel(excel_file)
iris_data
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
iris_data = pd.read_excel(excel_file, header = 1)
iris_data
# Out:
#      1  0.2  1.4  3.5  5.1       Setosa
# 0    1  0.2  1.4  3.0  4.9       Setosa
# 1    1  0.2  1.3  3.2  4.7       Setosa
# 2    1  0.2  1.5  3.1  4.6       Setosa
# 3    1  0.2  1.4  3.6  5.0       Setosa
# 4    1  0.4  1.7  3.9  5.4       Setosa
# 5    1  0.3  1.4  3.4  4.6       Setosa
# 6    1  0.2  1.5  3.4  5.0       Setosa
# 7    1  0.2  1.4  2.9  4.4       Setosa
# 8    1  0.1  1.5  3.1  4.9       Setosa
# 9    1  0.2  1.5  3.7  5.4       Setosa
# 10   1  0.2  1.6  3.4  4.8       Setosa
# 11   1  0.1  1.4  3.0  4.8       Setosa
# 12   1  0.1  1.1  3.0  4.3       Setosa
# 13   1  0.2  1.2  4.0  5.8       Setosa
# 14   1  0.4  1.5  4.4  5.7       Setosa
# 15   1  0.4  1.3  3.9  5.4       Setosa
# 16   1  0.3  1.4  3.5  5.1       Setosa
# 17   1  0.3  1.7  3.8  5.7       Setosa
# 18   1  0.3  1.5  3.8  5.1       Setosa
# 19   1  0.2  1.7  3.4  5.4       Setosa
# 20   1  0.4  1.5  3.7  5.1       Setosa
# 21   1  0.2  1.0  3.6  4.6       Setosa
# ...

# %%
# use the names parameter to specify the column names explicitly
cols = ['Species_No', 'Petal_width', 'Petal_length', 'Sepal_width', 'Sepal_length', 'Species_name']
df = pd.read_excel('Iris.xls', header=1, names=cols)
df
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.0           4.9
# 1             1          0.2           1.3          3.2           4.7
# 2             1          0.2           1.5          3.1           4.6
# 3             1          0.2           1.4          3.6           5.0
# 4             1          0.4           1.7          3.9           5.4
# ..          ...          ...           ...          ...           ...
# 144           3          2.3           5.2          3.0           6.7
# 145           3          1.9           5.0          2.5           6.3
# 146           3          2.0           5.2          3.0           6.5
# 147           3          2.3           5.4          3.4           6.2
# 148           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
# skiprows parameter to skip the header rows and read the data starting from a specific row.
df = pd.read_excel('Iris.xls', skiprows=[0, 1, 2], header=None)
df
# Out:
#      0    1    2    3    4           5
# 0    1  0.2  1.3  3.2  4.7      Setosa
# 1    1  0.2  1.5  3.1  4.6      Setosa
# 2    1  0.2  1.4  3.6  5.0      Setosa
# 3    1  0.4  1.7  3.9  5.4      Setosa
# 4    1  0.3  1.4  3.4  4.6      Setosa
# ..  ..  ...  ...  ...  ...         ...
# 143  3  2.3  5.2  3.0  6.7   Verginica
# 144  3  1.9  5.0  2.5  6.3   Verginica
# 145  3  2.0  5.2  3.0  6.5   Verginica
# 146  3  2.3  5.4  3.4  6.2   Verginica
# 147  3  1.8  5.1  3.0  5.9   Verginica
#
# [148 rows x 6 columns]

# %%
#specify that all rows should be shown
pd.set_option('display.max_rows', None)
df
# Out:
#      0    1    2    3    4            5
# 0    1  0.2  1.3  3.2  4.7       Setosa
# 1    1  0.2  1.5  3.1  4.6       Setosa
# 2    1  0.2  1.4  3.6  5.0       Setosa
# 3    1  0.4  1.7  3.9  5.4       Setosa
# 4    1  0.3  1.4  3.4  4.6       Setosa
# 5    1  0.2  1.5  3.4  5.0       Setosa
# 6    1  0.2  1.4  2.9  4.4       Setosa
# 7    1  0.1  1.5  3.1  4.9       Setosa
# 8    1  0.2  1.5  3.7  5.4       Setosa
# 9    1  0.2  1.6  3.4  4.8       Setosa
# 10   1  0.1  1.4  3.0  4.8       Setosa
# 11   1  0.1  1.1  3.0  4.3       Setosa
# 12   1  0.2  1.2  4.0  5.8       Setosa
# 13   1  0.4  1.5  4.4  5.7       Setosa
# 14   1  0.4  1.3  3.9  5.4       Setosa
# 15   1  0.3  1.4  3.5  5.1       Setosa
# 16   1  0.3  1.7  3.8  5.7       Setosa
# 17   1  0.3  1.5  3.8  5.1       Setosa
# 18   1  0.2  1.7  3.4  5.4       Setosa
# 19   1  0.4  1.5  3.7  5.1       Setosa
# 20   1  0.2  1.0  3.6  4.6       Setosa
# 21   1  0.5  1.7  3.3  5.1       Setosa
# ...

# %% [markdown]
# # Reading Data from CSV Files

# %%
# CSV files are mainly used for storing relational data and are quick and easy to use with Python and Jupyter.
# Pandas provides the read_csv() function that can load the data in any environment and provides features to analyze and visualize the loaded data

# csv file path
csv_file = 'Iris.csv'

# %%
# load data from the CSV file
iris_csv_data = pd.read_csv('Iris.csv')

# %%
# check the first few rows of data loaded from CSV
iris_csv_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# The read_csv() function also supports different arguments to:

# Load specific columns:

# Syntax: df = pd.read_csv('filename.csv', usecols=['column1', 'column2'])
df = pd.read_csv('Iris.csv', usecols=['sepal.length', 'sepal.width', 'variety'])
df
# Out:
#      sepal.length  sepal.width     variety
# 0             5.1          3.5      Setosa
# 1             4.9          3.0      Setosa
# 2             4.7          3.2      Setosa
# 3             4.6          3.1      Setosa
# 4             5.0          3.6      Setosa
# 5             5.4          3.9      Setosa
# 6             4.6          3.4      Setosa
# 7             5.0          3.4      Setosa
# 8             4.4          2.9      Setosa
# 9             4.9          3.1      Setosa
# 10            5.4          3.7      Setosa
# 11            4.8          3.4      Setosa
# 12            4.8          3.0      Setosa
# 13            4.3          3.0      Setosa
# 14            5.8          4.0      Setosa
# 15            5.7          4.4      Setosa
# 16            5.4          3.9      Setosa
# 17            5.1          3.5      Setosa
# 18            5.7          3.8      Setosa
# 19            5.1          3.8      Setosa
# 20            5.4          3.4      Setosa
# ...

# %%
#Skip erroneous rows:

# Syntax: df = pd.read_csv('filename.csv', error_bad_lines=False)
df = pd.read_csv('Iris.csv', on_bad_lines = "skip")
df

# %%
#Break files into chunks:
chunk_iter = pd.read_csv('Iris.csv', chunksize=10)
chunk_iter

# %% [markdown]
# # Reading Data from JSON Files

# %% [markdown]
# - JSON is a simple, lightweight, and widely used data format that stores data in human-readable format. <br><br>
#
# - It uses key-value pairs where each key is a string that uniquely identifies a value, which can be a string, number, boolean, array, or another JSON object. <br><br>
#
# - This format is commonly used for configuration files, responses from APIs, and data storage in various applications and is well suited for storing small-size dataset features.<br><br>

# %% [markdown]
# Pandas provide the <b>read_json()</b> method that helps you load the JSON files into a Dataframe.
#
# <br>An example to load the iris.json file using pandas will look like this:

# %%
# JSON file path
json_file = 'Iris.json'

# %%
# load data from the JSON file
iris_json_data = pd.read_json(json_file)

# %%
# check the first 5 rows of data loaded from JSON
iris_json_data.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %% [markdown]
# NOTE:
#
#     A helpful parameter for read_json() is the orient parameter. The orient parameter specifies the expected format of the JSON string or file. Using the correct orient value is crucial to ensure that the JSON data is read correctly into a DataFrame.
#
#     For instance, if your JSON file was formatted:
#
# [
# {"X": 1, "Y": 2},<br>
# {"X": 3, "Y": 4},<br>
# {"X": 5, "Y": 6}
# ]

# %% [markdown]
# ## Pandas also supports file formats such as XML, HDF5, HTML, LaTeX, Fixed-Width txt files, and others.
#
# Link [https://pandas.pydata.org/docs/user_guide/io.html]

# %% [markdown]
# # Accessing Data From Databases and Data Warehouses

# %% [markdown]
# - While file storage is good for small-size datasets, databases, and data warehouses are designed to hold almost any size of data.
#
# - Most organizations store their large amount of business-specific data in local or cloud databases such as MySQL, MongoDB, or PostgreSQL.
#
# - These databases are normally created, accessed, and managed using the Structured Query Language (SQL) for different business purposes.
#
# - Python provides a lot of connectors to access the data from different types of databases using the same SQL queries.
#
# - Pandas play a key role as you can read the queried data as a dataframe and perform multiple operations of your choice.

# %% [markdown]
# ## Accessing Data from SQLite DB

# %% [markdown]
# - <b>SQLite</b>
#     - Is a C language library that is used to implement lightweight disk-based databases that are small, fast, self-contained, and highly reliable. <br><br>
#     - This makes it popular across organizations for regular application development as these databases don’t require a separate server process and can be directly integrated into applications.<br><br>
#     - Python provides the sqlite3 module that can help you interact with SQLite databases. <br><br>
#     - No need to install this dependency as it already comes preinstalled with Python>2.5. <br><br>
#     - To select data from the SQLite database the code will look like this:<br>

# %%
# import dependency - Link: https://docs.python.org/3/library/sqlite3.html
import sqlite3 as sql

# %%
# create a connection to the database and a cursor to execute queries
conn = sql.connect('demo.db')
cur = conn.cursor()

# %%
cur.execute("CREATE TABLE movie(title, year, score)")

# %%
res = cur.execute("SELECT name FROM sqlite_master")
res.fetchone()
('movie',)

# %%
res = cur.execute("SELECT name FROM sqlite_master WHERE name='spam'")
res.fetchone() is None

# %%
cur.execute("""
    INSERT INTO movie VALUES
        ('Monty Python and the Holy Grail', 1975, 8.2),
        ('And Now for Something Completely Different', 1971, 7.5)
""")

# %%
conn.commit()

# %%
# query data from database
query = "SELECT * FROM movie"
results = cur.execute(query).fetchall()

# %%
res = cur.execute("SELECT score FROM movie")
res.fetchall()

# %%
data = [
    ("Monty Python Live at the Hollywood Bowl", 1982, 7.9),
    ("Monty Python's The Meaning of Life", 1983, 7.5),
    ("Monty Python's Life of Brian", 1979, 8.0),
]
cur.executemany("INSERT INTO movie VALUES(?, ?, ?)", data)
conn.commit()  # Remember to commit the transaction after executing INSERT.

# %%
for row in cur.execute("SELECT year, title FROM movie ORDER BY year"):
    print(row)

# %%
conn.close()
new_con = sql.connect("tutorial.db")
new_cur = new_con.cursor()
res = new_cur.execute("SELECT title, year FROM movie ORDER BY score DESC")
title, year = res.fetchone()
print(f'The highest scoring Monty Python movie is {title!r}, released in {year}')

# %%
# create a DataFrame from the DB data
df = pd.DataFrame(results)
df

# %% [markdown]
# ### Tasks - Execute these queries

# %%
Filtering Data Using WHERE:
    SELECT column1, column2
    FROM tablename
    WHERE column1 = 'some_value';

Sorting Data with ORDER BY:
    SELECT column1, column2
    FROM tablename
    ORDER BY column1 DESC;   -- DESC for descending, ASC for ascending (which is default)
    
Limiting Results with LIMIT:
    SELECT column1, column2
    FROM tablename
    LIMIT 10 OFFSET 20;  -- Skips the first 20 records and fetches the next 10.

Fetching Unique Records with DISTINCT:
    SELECT DISTINCT column1
    FROM tablename;

# %% [markdown]
# ## Accessing Data from MySQL DB

# %% [markdown]
# - MySQL is one of the widely used relational database management systems that is used to store tabular data. <br>
#
# - Many organizations use this DB to store business data for different purposes due to its performance, reliability, and versatility. <br>
#
# - Python provides a lot of connector modules to connect to MySQL, one of them is mysql-connector. <br>
#
# - It can be downloaded using PIP as follows:<br>
# pip install mysql-connector

# %%
# import mysql dependency
import mysql.connector # cmd/terminal -> pip install 
import pandas as pd

# %%
# create a connection to the database
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Dev@rsh@19",
    database="testDb",
     auth_plugin='mysql_native_password'
)

# %%
# select data from DB table
query = "SELECT * FROM Person"
df = pd.read_sql(query, conn)
# Out:
# /var/folders/tm/fqksxf3x5xs5rzw5pgffjt0h0000gn/T/ipykernel_1376/919325624.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df
# Out:
#    ID LastName FirstName  Age
# 0   1     John       Doe   30
# 1   2     Jane     Smith   25
# 2   3     Mike   Johnson   45
# 3   1    Vipan         P   30
# 4   2    Anish         S   25
# 5   3    Sabin         B   45

# %% [markdown]
# # Accessing Data with APIs

# %% [markdown]
# - If data is coming from a source outside your organization, you’ll need to access the data using APIs.
#     - The process starts with sending a request containing different query parameters and access credentials to the       endpoint (the platform that contains the data).
#
# - When the credentials and query parameters are validated,
#     - the endpoint returns a response such as response code and the data you wanted to access (usually in JSON           format) otherwise it will throw an error.
#
# - When working on Python,
#     - the requests module helps you access the data using APIs of different platforms in the Jupyter environment.

# %%
# Import necessary libraries
import requests # cmd/terminal -> pip install requests 

# Specify the URL where the dataset is hosted
url = "https://pandas.pydata.org/docs/user_guide/10min.html#basic-data-structures-in-pandas"

# %%
# Send an HTTP GET request to the specified URL
response = requests.get(url)

# %%
# Print the HTTP status code (e.g., 200 for "OK", 404 for "Not Found")
print(response.status_code)
# Out:
# 200

# %%
# Print the JSON content of the response
print(response)
# Out:
# <Response [200]>

# %%
# Convert the JSON response to a pandas DataFrame
res = pd.DataFrame(response)

# Display the first 5 rows of the DataFrame
res.head(10)
# Out:
#                                                    0
# 0  b'\n<!DOCTYPE html>\n<html lang="en" data-cont...
# 1  b'evice-width, initial-scale=1.0" /><meta name...
# 2  b'ndas &#8212; pandas 2.2.2 documentation</tit...
# 3  b'torage.getItem("mode") || "";\n    document....
# 4  b'\n\n<link href="../_static/styles/theme.css?...
# 5  b'ap.css?digest=5b4479735964841361fd" rel="sty...
# 6  b'4841361fd" rel="stylesheet" />\n<link href="...
# 7  b'"stylesheet" />\n<link rel="preload" as="fon...
# 8  b'a-solid-900.woff2" />\n<link rel="preload" a...
# 9  b'onts/fa-brands-400.woff2" />\n<link rel="pre...
